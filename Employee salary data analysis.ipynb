# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv("salary_data.csv")
df2=pd.read_csv("position_salaries.csv")
#print(df)
plt.title("Experience and salary")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.scatter(df1['YearsExperience'],df1['Salary'])
plt.show()

from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(df['YearsExperience'],df['Salary'])
print(xtrain.shape,xtest.shape)



#Linear Regression

from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain.values.reshape(-1,1),ytrain)
pred=lr.predict(xtest.values.reshape(-1,1))
pred_train=lr.predict(xtrain.values.reshape(-1,1))
plt.title("Experience and salary")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.scatter(xtrain,ytrain)
plt.plot(xtrain,pred_train)
plt.show()
print("Mean absolute error",np.sum(np.abs(ytrain-pred_train))/ytrain.shape[0])
# Out:
# (22,) (8,)
# Mean absolute error 5282.058219721917

# %%
plt.title("Experience and salary")
plt.xlabel("Years of experience")
plt.ylabel("Salary")
plt.scatter(xtest,ytest)
plt.plot(xtest,pred)
plt.show()

# %%
print(df2)
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
plt.scatter(df2['Level'],df2['Salary'])
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg=PolynomialFeatures(degree=8)
X_poly=poly_reg.fit_transform(df2['Level'].values.reshape(-1,1))
lr=LinearRegression()
lr.fit(X_poly,df2['Salary'])

pred=lr.predict(X_poly)
plt.scatter(df2['Level'],df2['Salary'])
plt.plot(df2['Level'],pred)
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor 
from sklearn import datasets
data=datasets.load_diabetes()
x=pd.DataFrame(data.data,columns=data.feature_names)
y=data.target
#print(x.head())
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)
dtr=DecisionTreeRegressor()
dtr.fit(xtrain,ytrain)
pred=dtr.predict(xtest)
plt.plot(ytest)
plt.plot(pred)
plt.show()

# %%
from sklearn.metrics import r2_score
print(r2_score(ytest,pred))
# Out:
# 0.06432158364883422
